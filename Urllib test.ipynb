# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup as bs
thisurl = "http://www-rohan.sdsu.edu/~gawron/index.html"

handle = urlopen(thisurl)

html_gunk =  handle.read()

soup=bs(html_gunk)
contents=soup.text.strip("")
print(contents)
# Out:
# Jean Mark Gawron
#
#
#
# Jean Mark Gawron
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Classes
# Research
# Comp Ling Program
# Curriculum
# PGP Public key
# PGP key + Photo
# Explaining PGP
#
#
#
#
#
#
#
#
#
#
#
# Wordnet fragment: closeup of a set of semantically related
# words in Wordnet 3.
# This network represents only hyponym links and the starting point was the word
# dog.
# Hover your cursor over a node to see the corresponding word.
# Try selecting a node and moving it around.
# The network was rendered by Mike Bostock's set of javascript visualization
# tools, D3, via Drew Conway's networkx hooks.
# The colors are chosen by Thomas Aynaud's implementation of
# the Louvain community detection algorithm, which does a pretty
# good job of finding the numerous bits of local structure in this graph.
# Putting thse pieces together was inspired by
#
# Neal Caren's citation graph of Sociology papers.
# Those feeling
# adventurous may want to take a look at this much larger graph centered on the word person.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Department of Linguistics
# San Diego State University
# 5500 Campanile Dr.
# San Diego, CA 92182-7727
#
#
#
#
#
#
#
#
#
#
# "I have come to believe that the whole world is an enigma, a harmless enigma
# that is made terrible by our own mad attempt to interpret it as though it had
# an underlying truth."
# -- Umberto Eco
#
#
#
#
#
# Computational Linguistics Certificate
#
#
#
#
#
# The Computational Linguistics program at SDSU is
# offering a new certificate in Computational Linguistics for
# which undergrads, grads, and community members may qualify.
# Details
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Courses
#
#
#
# Spring 2016
#
#
#
#
#
# Ling 522
#
#
#    Intro to semantics
#
#
# Meaning: What is it?
#
#
#
#
# Ling 581
#
#
#    Intro to computational linguistics
#
#
# Computing with words & linguistic structure
#
#
#
#
# Ling 626
#
#
#    Pragmatics
#
#
# How to mean things (but not why)
#
#
#
#
#
#
#
# Fall 2015
#
#
#
#
#
# Ling 522
#
#
#    Intro to syntax
#
#
# Structure: What is it good for?
#
#
#
#
# Ling 572
#
#
#    Python for Social Science
#
#
# Coping with the data explosion
#
#
#
#
#
#
#
# Fall 2014
#
#
#
#
#
# Ling 522
#
#
#    Intro to syntax
#
#
# Structure: What is it good for?
#
#
#
#
# Ling 572
#
#
#    Python for Social Science
#
#
# Coping with the data explosion
#
#
#
#
#
#
#
# Spring 2014
#
#
#
#
#
# Ling 525
#
#
#    Intro to semantics
#
#
# Meaning: What is it?
#
#
#
#
# Ling 581
#
#
#    Intro to computational linguistics
#
#
# Computing with woids
#
#
#
#
# Ling 596
#
#
#    Python for social scientists
#
#
# Coping with the data explosion
#
#
#
#
#
#
#
# Fall 2013
#
#
#
#
#
# Ling 522
#
#
#    Intro to syntax
#
#
# Structure: What is it good for?
#
#
#
#
# Ling 570
#
#
#    Intro to mathematical linguistics
#
#
# Sets, logic, lattices, linguistic applications
#
#
#
#
#
#
#
# Spring 2013
#
#
#
#
#
#
#
# Ling 525
#
#
#    Intro to semantics
#
#
# Language: What does it mean?
#
#
#
#
# Ling 503
#
#
#    Functions of Language
#
#
# Language: What is it for?
#
#
#
#
# Ling 581
#
#
#    Intro to computational linguistics
#
#
# Computational approaches to language
#
#
#
#
#
#
# Fall 2012
#
#
#
#
#
#
#
# Ling 522
#
#
#    Intro to syntax
#
#
# Structure: What is it good for?
#
#
#
#
# Ling 570
#
#
#    Intro to mathematical linguistics
#
#
# Sets, logic, lattices, linguistic applications
#
#
#
#
#
#
# Spring 2012
#
#
#
#
#
#
#
# Ling 525
#
#
#    Intro to Semantics
#
#
# Meaning and form
#
#
#
#
# Ling 581
#
#
#    Computational Linguistics
#
#
# Processing words, sentences, documents
#
#
#
#
# Ling 501
#
#
#    Fundamentals of Ling
#
#
# Languistic structure and what it's good for
#
#
#
#
#
#
#
# Software
#  Word similarity tools.
#  Basic crawler module: A host of Python components implementing a basic crawler for data collection.
#  Archiver module: Presupposes crawler.  Creates archive of compressed text files,  WithTwitter data, can be used to store various augmented information in an Excel file, including page rank, and disabbreviated web links with title info.
#
# Recent Papers and Talks
#
#  The Lexical Semantics of Extent Verbs
# This version of the work descending from
# the "Generalized Paths" Salt paper is under submission and will be stable
# a while.
#  Argument Structure as soft constraints (talk
# given at Xerox Parc March 9, 2008)
#
# Interpreting Words (current draft entitled: Circumstances
# and Perspective: The Logic of Argument Structure)
#  Paths and the Language of Change (pdf, Old version,
# ps handout,
# ps handout)
#
# Generalized Paths
# (Salt XV handout,
# Salt XV paper,
# )
#
# Motion, Scalar Paths, and Lexical Aspect
# (pdf version)
#
# Frames and Lexical Semantics
# (ps version)
#
# Two Kinds of Determiner in DP
# (
#     LSA handout [postscript],
#
#   LSA  talk [postscript])
#
#  Handout contains a superset of the LSA talk handout
#  Talk contains read version of the LSA talk, some
# clarification of material in the handout
#
#
# Abduction and Mismatch in Machine Translation
# (pdf version,
#  ps version)
#  Universal Concessive Conditionals (
# ps,
# pdf)
#
# Projects
#
#  Mapping ideas
#  Machine Translation
# with FrameNet
#  Gemini
#  Spoken Language Systems
#
# Bill Evans
#
# Oddz Endz
#
#
# Cynthia Shelmerdine's Icarus page  (especially Muriel Rukeyser's
# contribution)
#  John Sayles
#
# Jane Smiley (Not that fond of Private Lives, but
# Horse Heaven, A Thousand Acres, Moo,
# Ten Days in the Hills, Duplicate Keys and Good Faith
# are not only all stunning, but stunning in their variety)
#  The Adventures of the Black Girl in her Search for God. G. B. Shaw.
#
# Corpora and Resources
#
#
# Japanese English aligned texts
#
#
#
#
#
#
# Novels
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Other Stuff: Google, Alta Vista
# Other Things to Do
#
# HTML book
#  Dr.HTML will fix your web page
#  Dictionaries: Bucknell dictionaries,
# EMich dictionaries
#
#
#
#  Jean Mark Gawron
#  SDSU, 5900 Campanile Drive, San Diego, CA 92182-7717
#
#
# Last modified: Tue Aug 22 15:39:48 2000

# %%
html_gunk[:150]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-02c54316fd59> in <module>()
# ----> 1 html_gunk[:150]
#
# NameError: name 'html_gunk' is not defined

# %%
import html.parser
import urllib

urlText = []

#Define HTML Parser
class parseText(HTMLParser.HTMLParser):
        
    def handle_data(self, data):
        if data != '\n':
            urlText.append(data)
    

#Create instance of HTML parser
lParser = parseText()

thisurl = "http://www-rohan.sdsu.edu/~gawron/index.html"
#Feed HTML file into parser
lParser.feed(urllib.urlopen(thisurl).read())
lParser.close()
for item in urlText:
    print (item)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-4f8aa0cd531c> in <module>()
#       5
#       6 #Define HTML Parser
# ----> 7 class parseText(HTMLParser.HTMLParser):
#       8
#       9     def handle_data(self, data):
#
# AttributeError: type object 'HTMLParser' has no attribute 'HTMLParser'
